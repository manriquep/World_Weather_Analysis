# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | jinchang
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | harper
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | cayenne
# Processing Record 8 of Set 1 | pouebo
# Processing Record 9 of Set 1 | ashland
# Processing Record 10 of Set 1 | burns lake
# Processing Record 11 of Set 1 | nueva loja
# Processing Record 12 of Set 1 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 1 | karpathos
# Processing Record 14 of Set 1 | meulaboh
# Processing Record 15 of Set 1 | port hardy
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | moldava nad bodvou
# Processing Record 21 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | lavrentiya
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | dali
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | erenhot
# Processing Record 33 of Set 1 | general roca
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | dicabisagan
# Processing Record 36 of Set 1 | limon
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | buta
# Processing Record 39 of Set 1 | tugulym
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | caravelas
# Processing Record 42 of Set 1 | hirado
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | dingle
# Processing Record 48 of Set 1 | comodoro rivadavia
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | dwarka
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | maltahohe
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | paamiut
# Processing Record 5 of Set 2 | el sauzal
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | san patricio
# Processing Record 8 of Set 2 | xiongyue
# Processing Record 9 of Set 2 | alofi
# Processing Record 10 of Set 2 | kyra
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | sibolga
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | aginskoye
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | kloulklubed
# Processing Record 19 of Set 2 | lata
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | adrar
# Processing Record 22 of Set 2 | mogoytuy
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | forquilhinha
# Processing Record 28 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | broome
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | vila
# Processing Record 33 of Set 2 | misratah
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | bardiyah
# Processing Record 36 of Set 2 | naryan-mar
# Processing Record 37 of Set 2 | yerbogachen
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | gat
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | raymondville
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | mosjoen
# Processing Record 1 of Set 3 | ossora
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 3 | half moon bay
# Processing Record 5 of Set 3 | bonfim
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | nioki
# Processing Record 10 of Set 3 | san cristobal
# Processing Record 11 of Set 3 | portland
# Processing Record 12 of Set 3 | solone
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | mogadishu
# Processing Record 15 of Set 3 | bima
# Processing Record 16 of Set 3 | sena madureira
# Processing Record 17 of Set 3 | kuytun
# Processing Record 18 of Set 3 | platanos
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | cheremukhovo
# Processing Record 21 of Set 3 | grindavik
# Processing Record 22 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 3 | tarko-sale
# Processing Record 24 of Set 3 | estelle
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | huilong
# Processing Record 27 of Set 3 | tazmalt
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | buala
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | bolshaya murta
# City not found. Skipping...
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | krasnyy klyuch
# Processing Record 34 of Set 3 | nhulunbuy
# Processing Record 35 of Set 3 | san vicente
# Processing Record 36 of Set 3 | aktas
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | constancia
# Processing Record 39 of Set 3 | aquiraz
# Processing Record 40 of Set 3 | alim
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | husavik
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | vallenar
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | the valley
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | sydney
# Processing Record 3 of Set 4 | carauari
# Processing Record 4 of Set 4 | perugia
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | bilibino
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | badnawar
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | purepero
# Processing Record 12 of Set 4 | cornwall
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | atasu
# Processing Record 15 of Set 4 | hays
# Processing Record 16 of Set 4 | alice springs
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | zhezkazgan
# Processing Record 22 of Set 4 | oktyabrskoye
# Processing Record 23 of Set 4 | luba
# Processing Record 24 of Set 4 | camocim
# Processing Record 25 of Set 4 | flinders
# Processing Record 26 of Set 4 | roma
# Processing Record 27 of Set 4 | la ronge
# Processing Record 28 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 29 of Set 4 | nassau
# Processing Record 30 of Set 4 | elbrus
# Processing Record 31 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 4 | beckley
# Processing Record 33 of Set 4 | inta
# Processing Record 34 of Set 4 | victoria
# Processing Record 35 of Set 4 | santa cruz de la palma
# Processing Record 36 of Set 4 | lasa
# Processing Record 37 of Set 4 | rapid valley
# Processing Record 38 of Set 4 | boguchany
# Processing Record 39 of Set 4 | geraldton
# Processing Record 40 of Set 4 | francistown
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | ler
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | sinnamary
# Processing Record 45 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | vao
# Processing Record 50 of Set 4 | sarangani
# Processing Record 1 of Set 5 | westport
# Processing Record 2 of Set 5 | riberalta
# Processing Record 3 of Set 5 | qaqortoq
# Processing Record 4 of Set 5 | deputatskiy
# Processing Record 5 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | jamestown
# Processing Record 8 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 5 | tiznit
# Processing Record 10 of Set 5 | cap malheureux
# Processing Record 11 of Set 5 | manggar
# Processing Record 12 of Set 5 | shenjiamen
# Processing Record 13 of Set 5 | korla
# Processing Record 14 of Set 5 | veraval
# Processing Record 15 of Set 5 | okhotsk
# Processing Record 16 of Set 5 | cervo
# Processing Record 17 of Set 5 | qasigiannguit
# Processing Record 18 of Set 5 | arkadak
# Processing Record 19 of Set 5 | ojinaga
# Processing Record 20 of Set 5 | tomatlan
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | araouane
# Processing Record 24 of Set 5 | mackenzie
# Processing Record 25 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 5 | sao joao da barra
# Processing Record 27 of Set 5 | yellowknife
# Processing Record 28 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | rorvik
# Processing Record 31 of Set 5 | smolenskaya
# Processing Record 32 of Set 5 | ixtapa
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | ulverstone
# Processing Record 35 of Set 5 | kachug
# Processing Record 36 of Set 5 | puri
# Processing Record 37 of Set 5 | kodinar
# Processing Record 38 of Set 5 | guerrero negro
# Processing Record 39 of Set 5 | witrivier
# City not found. Skipping...
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | sobolevo
# Processing Record 43 of Set 5 | pacific grove
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | vicente guerrero
# Processing Record 46 of Set 5 | livingston
# Processing Record 47 of Set 5 | sulangan
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | okha
# Processing Record 50 of Set 5 | arona
# Processing Record 1 of Set 6 | cabinda
# Processing Record 2 of Set 6 | sisophon
# Processing Record 3 of Set 6 | lubango
# Processing Record 4 of Set 6 | boende
# Processing Record 5 of Set 6 | sorland
# Processing Record 6 of Set 6 | tecoh
# Processing Record 7 of Set 6 | tam ky
# Processing Record 8 of Set 6 | manavalakurichi
# Processing Record 9 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 10 of Set 6 | tiarei
# Processing Record 11 of Set 6 | beloha
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | nalut
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 16 of Set 6 | camopi
# Processing Record 17 of Set 6 | konevo
# Processing Record 18 of Set 6 | santa cruz del norte
# Processing Record 19 of Set 6 | pushchino
# Processing Record 20 of Set 6 | necochea
# Processing Record 21 of Set 6 | aranos
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | shahr-e babak
# Processing Record 24 of Set 6 | jaramana
# City not found. Skipping...
# Processing Record 25 of Set 6 | saint-francois
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | xingyi
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | skibbereen
# Processing Record 30 of Set 6 | hami
# Processing Record 31 of Set 6 | quang ngai
# Processing Record 32 of Set 6 | ozernovskiy
# Processing Record 33 of Set 6 | itoman
# Processing Record 34 of Set 6 | mantua
# Processing Record 35 of Set 6 | vanavara
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | morehead
# Processing Record 38 of Set 6 | burnie
# Processing Record 39 of Set 6 | kichha
# Processing Record 40 of Set 6 | sao domingos
# Processing Record 41 of Set 6 | monywa
# Processing Record 42 of Set 6 | provideniya
# Processing Record 43 of Set 6 | rawson
# Processing Record 44 of Set 6 | inuvik
# Processing Record 45 of Set 6 | shimanovsk
# Processing Record 46 of Set 6 | fuerte olimpo
# Processing Record 47 of Set 6 | luanda
# Processing Record 48 of Set 6 | richards bay
# Processing Record 49 of Set 6 | iqaluit
# Processing Record 50 of Set 6 | upernavik
# Processing Record 1 of Set 7 | slobodskoy
# Processing Record 2 of Set 7 | youhao
# Processing Record 3 of Set 7 | zheleznodorozhnyy
# Processing Record 4 of Set 7 | dunedin
# Processing Record 5 of Set 7 | fuyang
# Processing Record 6 of Set 7 | cockburn town
# Processing Record 7 of Set 7 | isla vista
# Processing Record 8 of Set 7 | qaanaaq
# Processing Record 9 of Set 7 | kampong thum
# Processing Record 10 of Set 7 | rivers
# Processing Record 11 of Set 7 | owensboro
# Processing Record 12 of Set 7 | pulandian
# Processing Record 13 of Set 7 | bereda
# Processing Record 14 of Set 7 | kenai
# Processing Record 15 of Set 7 | saint-louis
# Processing Record 16 of Set 7 | barentu
# Processing Record 17 of Set 7 | niesky
# Processing Record 18 of Set 7 | kholm-zhirkovskiy
# Processing Record 19 of Set 7 | ponerihouen
# Processing Record 20 of Set 7 | port arthur
# Processing Record 21 of Set 7 | suntar
# Processing Record 22 of Set 7 | nanakuli
# Processing Record 23 of Set 7 | guangyuan
# Processing Record 24 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 7 | juigalpa
# Processing Record 26 of Set 7 | broken hill
# Processing Record 27 of Set 7 | madang
# Processing Record 28 of Set 7 | carmaux
# Processing Record 29 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | maldonado
# Processing Record 32 of Set 7 | saldanha
# Processing Record 33 of Set 7 | karmala
# Processing Record 34 of Set 7 | faanui
# Processing Record 35 of Set 7 | ugoofaaru
# Processing Record 36 of Set 7 | gizo
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | acajutla
# Processing Record 39 of Set 7 | khandyga
# Processing Record 40 of Set 7 | ocos
# Processing Record 41 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 7 | labuhan
# Processing Record 43 of Set 7 | kununurra
# Processing Record 44 of Set 7 | coihaique
# Processing Record 45 of Set 7 | mokhsogollokh
# Processing Record 46 of Set 7 | nouakchott
# Processing Record 47 of Set 7 | searcy
# Processing Record 48 of Set 7 | oistins
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | innisfail
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | tessalit
# Processing Record 3 of Set 8 | codrington
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | gillette
# Processing Record 6 of Set 8 | ziro
# Processing Record 7 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 8 | colorado springs
# Processing Record 9 of Set 8 | caledon
# Processing Record 10 of Set 8 | elliot lake
# Processing Record 11 of Set 8 | arivonimamo
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | sur
# Processing Record 14 of Set 8 | wahiawa
# Processing Record 15 of Set 8 | jiayuguan
# Processing Record 16 of Set 8 | ghanzi
# Processing Record 17 of Set 8 | saint-pierre
# Processing Record 18 of Set 8 | tevaitoa
# Processing Record 19 of Set 8 | san policarpo
# Processing Record 20 of Set 8 | guarapari
# Processing Record 21 of Set 8 | gamba
# Processing Record 22 of Set 8 | carutapera
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | buy
# Processing Record 25 of Set 8 | aykhal
# Processing Record 26 of Set 8 | la libertad
# Processing Record 27 of Set 8 | arman
# Processing Record 28 of Set 8 | almaznyy
# Processing Record 29 of Set 8 | ilulissat
# Processing Record 30 of Set 8 | oum hadjer
# Processing Record 31 of Set 8 | grand-lahou
# Processing Record 32 of Set 8 | takoradi
# Processing Record 33 of Set 8 | lanzhou
# Processing Record 34 of Set 8 | dolores
# Processing Record 35 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 8 | kui buri
# Processing Record 37 of Set 8 | kuala krai
# City not found. Skipping...
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | saint george
# Processing Record 40 of Set 8 | garsten
# Processing Record 41 of Set 8 | dustlik
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | amapa
# Processing Record 44 of Set 8 | freire
# Processing Record 45 of Set 8 | chinameca
# Processing Record 46 of Set 8 | la primavera
# Processing Record 47 of Set 8 | yar-sale
# Processing Record 48 of Set 8 | katsuura
# Processing Record 49 of Set 8 | fukue
# Processing Record 50 of Set 8 | berlevag
# Processing Record 1 of Set 9 | miandrivazo
# Processing Record 2 of Set 9 | araceli
# Processing Record 3 of Set 9 | umm lajj
# Processing Record 4 of Set 9 | athabasca
# Processing Record 5 of Set 9 | berdigestyakh
# Processing Record 6 of Set 9 | bundibugyo
# Processing Record 7 of Set 9 | barra do bugres
# Processing Record 8 of Set 9 | volkhovskiy
# Processing Record 9 of Set 9 | saint-paul
# Processing Record 10 of Set 9 | kondinskoye
# Processing Record 11 of Set 9 | cabo san lucas
# Processing Record 12 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | neyshabur
# Processing Record 15 of Set 9 | evensk
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | dagua
# Processing Record 18 of Set 9 | yarovoye
# Processing Record 19 of Set 9 | mandera
# Processing Record 20 of Set 9 | knysna
# Processing Record 21 of Set 9 | faya
# Processing Record 22 of Set 9 | kashi
# Processing Record 23 of Set 9 | beringovskiy
# Processing Record 24 of Set 9 | ahuimanu
# Processing Record 25 of Set 9 | verkhnyaya inta
# Processing Record 26 of Set 9 | puerto escondido
# Processing Record 27 of Set 9 | nanortalik
# Processing Record 28 of Set 9 | urengoy
# Processing Record 29 of Set 9 | kargil
# Processing Record 30 of Set 9 | biskamzha
# Processing Record 31 of Set 9 | kusadak
# Processing Record 32 of Set 9 | souillac
# Processing Record 33 of Set 9 | santiago
# Processing Record 34 of Set 9 | canete
# Processing Record 35 of Set 9 | tecoanapa
# Processing Record 36 of Set 9 | mocuba
# Processing Record 37 of Set 9 | surab
# Processing Record 38 of Set 9 | gorin
# Processing Record 39 of Set 9 | abrego
# Processing Record 40 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 43 of Set 9 | alappuzha
# Processing Record 44 of Set 9 | port moresby
# Processing Record 45 of Set 9 | man
# Processing Record 46 of Set 9 | grand-santi
# Processing Record 47 of Set 9 | denpasar
# Processing Record 48 of Set 9 | nome
# Processing Record 49 of Set 9 | yanam
# Processing Record 50 of Set 9 | beidao
# Processing Record 1 of Set 10 | ornskoldsvik
# Processing Record 2 of Set 10 | yangjiang
# Processing Record 3 of Set 10 | egvekinot
# Processing Record 4 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | nadym
# Processing Record 7 of Set 10 | kilindoni
# Processing Record 8 of Set 10 | bella union
# Processing Record 9 of Set 10 | khani
# Processing Record 10 of Set 10 | henties bay
# Processing Record 11 of Set 10 | vyazemskiy
# Processing Record 12 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 10 | floresti
# Processing Record 14 of Set 10 | pires do rio
# Processing Record 15 of Set 10 | lincoln
# Processing Record 16 of Set 10 | basco
# Processing Record 17 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 10 | namibe
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | xunchang
# Processing Record 21 of Set 10 | rajur
# Processing Record 22 of Set 10 | urucara
# Processing Record 23 of Set 10 | arinos
# Processing Record 24 of Set 10 | tombouctou
# Processing Record 25 of Set 10 | nyurba
# Processing Record 26 of Set 10 | matara
# Processing Record 27 of Set 10 | moron
# Processing Record 28 of Set 10 | lompoc
# Processing Record 29 of Set 10 | marsh harbour
# Processing Record 30 of Set 10 | alenquer
# Processing Record 31 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | gobabis
# Processing Record 34 of Set 10 | margate
# Processing Record 35 of Set 10 | aripuana
# Processing Record 36 of Set 10 | ario
# City not found. Skipping...
# Processing Record 37 of Set 10 | tocopilla
# Processing Record 38 of Set 10 | viedma
# Processing Record 39 of Set 10 | petropavl
# Processing Record 40 of Set 10 | kapuskasing
# Processing Record 41 of Set 10 | jamui
# Processing Record 42 of Set 10 | north bend
# Processing Record 43 of Set 10 | nuevitas
# Processing Record 44 of Set 10 | luderitz
# Processing Record 45 of Set 10 | tadine
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | xuddur
# Processing Record 48 of Set 10 | mana
# Processing Record 49 of Set 10 | abu dhabi
# Processing Record 50 of Set 10 | vardo
# Processing Record 1 of Set 11 | curanilahue
# Processing Record 2 of Set 11 | oranjemund
# Processing Record 3 of Set 11 | san juan
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | umea
# Processing Record 6 of Set 11 | grand gaube
# Processing Record 7 of Set 11 | coquimbo
# Processing Record 8 of Set 11 | point pedro
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | rosarito
# Processing Record 11 of Set 11 | palana
# Processing Record 12 of Set 11 | laredo
# Processing Record 13 of Set 11 | zabid
# Processing Record 14 of Set 11 | christchurch
# Processing Record 15 of Set 11 | tsiroanomandidy
# Processing Record 16 of Set 11 | mwense
# Processing Record 17 of Set 11 | tiksi
# Processing Record 18 of Set 11 | winnemucca
# Processing Record 19 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 11 | beira
# Processing Record 21 of Set 11 | andros town
# Processing Record 22 of Set 11 | dashitou
# Processing Record 23 of Set 11 | ipameri
# Processing Record 24 of Set 11 | bati
# Processing Record 25 of Set 11 | kokopo
# Processing Record 26 of Set 11 | megion
# Processing Record 27 of Set 11 | plouzane
# Processing Record 28 of Set 11 | burica
# City not found. Skipping...
# Processing Record 29 of Set 11 | batemans bay
# Processing Record 30 of Set 11 | kanigiri
# Processing Record 31 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 32 of Set 11 | ampanihy
# Processing Record 33 of Set 11 | hellvik
# Processing Record 34 of Set 11 | barcelos
# Processing Record 35 of Set 11 | wenatchee
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | ulladulla
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | xuanhua
# Processing Record 40 of Set 11 | bowen
# Processing Record 41 of Set 11 | port keats
# Processing Record 42 of Set 11 | pelym
# Processing Record 43 of Set 11 | bonavista
# Processing Record 44 of Set 11 | taltal
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | chadiza
# Processing Record 47 of Set 11 | bubaque
# Processing Record 48 of Set 11 | cua
# Processing Record 49 of Set 11 | xichang
# Processing Record 50 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 12 | hyeres
# Processing Record 2 of Set 12 | vagay
# Processing Record 3 of Set 12 | sinnar
# Processing Record 4 of Set 12 | marzuq
# Processing Record 5 of Set 12 | paranaiba
# Processing Record 6 of Set 12 | awjilah
# Processing Record 7 of Set 12 | morro bay
# Processing Record 8 of Set 12 | colares
# Processing Record 9 of Set 12 | balurghat
# Processing Record 10 of Set 12 | santa cruz
# Processing Record 11 of Set 12 | cilegon
# Processing Record 12 of Set 12 | micheweni
# Processing Record 13 of Set 12 | santa maria
# Processing Record 14 of Set 12 | ratangarh
# Processing Record 15 of Set 12 | ronne
# Processing Record 16 of Set 12 | phan thiet
# Processing Record 17 of Set 12 | mouzouras
# Processing Record 18 of Set 12 | sechelt
# Processing Record 19 of Set 12 | kotka
# Processing Record 20 of Set 12 | saurimo
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | sibut
# Processing Record 23 of Set 12 | chumikan
# Processing Record 24 of Set 12 | tucurui
# Processing Record 25 of Set 12 | puerto ayacucho
# Processing Record 26 of Set 12 | springfield
# Processing Record 27 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 12 | sao felix do xingu
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 12 | kirovskiy
# Processing Record 32 of Set 12 | klyuchi
# Processing Record 33 of Set 12 | huainan
# Processing Record 34 of Set 12 | qiongshan
# Processing Record 35 of Set 12 | leningradskiy
# Processing Record 36 of Set 12 | sawakin
# Processing Record 37 of Set 12 | awash
# Processing Record 38 of Set 12 | yablochnyy
# Processing Record 39 of Set 12 | kambove
# Processing Record 40 of Set 12 | tarauaca
# Processing Record 41 of Set 12 | padang
# Processing Record 42 of Set 12 | trogir
# Processing Record 43 of Set 12 | walvis bay
# Processing Record 44 of Set 12 | sosnovoborsk
# Processing Record 45 of Set 12 | isangel
# Processing Record 46 of Set 12 | eckernforde
# Processing Record 47 of Set 12 | grootfontein
# Processing Record 48 of Set 12 | santa cruz cabralia
# Processing Record 49 of Set 12 | wanxian
# Processing Record 50 of Set 12 | ust-omchug
# Processing Record 1 of Set 13 | inhambane
# Processing Record 2 of Set 13 | shingu
# Processing Record 3 of Set 13 | fairview
# Processing Record 4 of Set 13 | bafq
# Processing Record 5 of Set 13 | teruel
# Processing Record 6 of Set 13 | portugalete
# Processing Record 7 of Set 13 | rawlins
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | sayyan
# Processing Record 10 of Set 13 | eresos
# Processing Record 11 of Set 13 | karauli
# Processing Record 12 of Set 13 | liepaja
# Processing Record 13 of Set 13 | khasan
# Processing Record 14 of Set 13 | pemberton
# Processing Record 15 of Set 13 | pangnirtung
# Processing Record 16 of Set 13 | fort nelson
# Processing Record 17 of Set 13 | akdagmadeni
# Processing Record 18 of Set 13 | fayaoue
# Processing Record 19 of Set 13 | ekibastuz
# Processing Record 20 of Set 13 | monzon
# Processing Record 21 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 13 | yarada
# Processing Record 23 of Set 13 | brae
# Processing Record 24 of Set 13 | surman
# Processing Record 25 of Set 13 | kemijarvi
# Processing Record 26 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 13 | alpoyeca
# Processing Record 28 of Set 13 | potosi
# Processing Record 29 of Set 13 | saint combs
# City not found. Skipping...
# Processing Record 30 of Set 13 | yongan
# Processing Record 31 of Set 13 | butajira
# Processing Record 32 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | yulara
# Processing Record 35 of Set 13 | loreto
# Processing Record 36 of Set 13 | santo antonio do monte
# Processing Record 37 of Set 13 | olinda
# Processing Record 38 of Set 13 | romny
# Processing Record 39 of Set 13 | vostok
# Processing Record 40 of Set 13 | kasulu
# Processing Record 41 of Set 13 | north platte
# Processing Record 42 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 13 | oxapampa
# Processing Record 44 of Set 13 | kalabo
# Processing Record 45 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | aurora
# Processing Record 48 of Set 13 | hofn
# Processing Record 49 of Set 13 | zamora
# Processing Record 50 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 14 | cabedelo
# Processing Record 2 of Set 14 | asau
# Processing Record 3 of Set 14 | goaigoaza
# City not found. Skipping...
# Processing Record 4 of Set 14 | kysyl-syr
# Processing Record 5 of Set 14 | vezirkopru
# Processing Record 6 of Set 14 | xining
# Processing Record 7 of Set 14 | mayor pablo lagerenza
# Processing Record 8 of Set 14 | rockland
# Processing Record 9 of Set 14 | sechura
# Processing Record 10 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 14 | sambava
# Processing Record 12 of Set 14 | san quintin
# Processing Record 13 of Set 14 | koumac
# Processing Record 14 of Set 14 | soubre
# Processing Record 15 of Set 14 | gazojak
# Processing Record 16 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 14 | nizhnyaya poyma
# Processing Record 18 of Set 14 | plumbon
# Processing Record 19 of Set 14 | santiago del estero
# Processing Record 20 of Set 14 | maiduguri
# Processing Record 21 of Set 14 | taoudenni
# Processing Record 22 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 23 of Set 14 | ironton
# Processing Record 24 of Set 14 | waipawa
# Processing Record 25 of Set 14 | mihijam
# Processing Record 26 of Set 14 | williamsburg
# Processing Record 27 of Set 14 | ayan
# Processing Record 28 of Set 14 | wilmington
# Processing Record 29 of Set 14 | sorong
# Processing Record 30 of Set 14 | la palma
# Processing Record 31 of Set 14 | bilma
# Processing Record 32 of Set 14 | ostersund
# Processing Record 33 of Set 14 | tautira
# Processing Record 34 of Set 14 | sulya
# Processing Record 35 of Set 14 | taunggyi
# Processing Record 36 of Set 14 | sept-iles
# Processing Record 37 of Set 14 | yuanping
# Processing Record 38 of Set 14 | teknaf
# Processing Record 39 of Set 14 | vossevangen
# Processing Record 40 of Set 14 | ilabaya
# Processing Record 41 of Set 14 | bam
# Processing Record 42 of Set 14 | tripoli
# Processing Record 43 of Set 14 | constitucion
# Processing Record 44 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 14 | raudeberg
# Processing Record 46 of Set 14 | nantucket
# Processing Record 47 of Set 14 | muriwai beach
# Processing Record 48 of Set 14 | marsa matruh
# Processing Record 49 of Set 14 | ovalle
# Processing Record 50 of Set 14 | fez
# Processing Record 1 of Set 15 | poum
# Processing Record 2 of Set 15 | mitsamiouli
# Processing Record 3 of Set 15 | rianxo
# Processing Record 4 of Set 15 | batticaloa
# Processing Record 5 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 8 of Set 15 | maniitsoq
# Processing Record 9 of Set 15 | el badari
# City not found. Skipping...
# Processing Record 10 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 11 of Set 15 | buckeye
# Processing Record 12 of Set 15 | tucuman
# Processing Record 13 of Set 15 | kathmandu
# Processing Record 14 of Set 15 | zhaotong
# Processing Record 15 of Set 15 | pitimbu
# Processing Record 16 of Set 15 | buraydah
# Processing Record 17 of Set 15 | haapiti
# Processing Record 18 of Set 15 | karak
# Processing Record 19 of Set 15 | mbandaka
# Processing Record 20 of Set 15 | xihe
# Processing Record 21 of Set 15 | northam
# Processing Record 22 of Set 15 | plymouth
# Processing Record 23 of Set 15 | mahibadhoo
# Processing Record 24 of Set 15 | sajanan
# Processing Record 25 of Set 15 | tirano
# Processing Record 26 of Set 15 | cubuk
# Processing Record 27 of Set 15 | novoagansk
# Processing Record 28 of Set 15 | kieta
# Processing Record 29 of Set 15 | san jose
# Processing Record 30 of Set 15 | miyako
# Processing Record 31 of Set 15 | baker city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# tally the number of cities in the city_data array
len(city_data)
# Out:
# 663

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     79.00        72           1
# 1  Arraial Do Cabo -22.9661  -42.0278     78.80        83           0
# 2         Jinchang  38.4953  102.1739     47.73        16          82
# 3     Port Lincoln -34.7333  135.8667     65.08        59          33
# 4           Harper   4.3750   -7.7169     78.30        90           1
# 5           Atuona  -9.8000 -139.0333     80.92        75          27
# 6          Cayenne   4.9333  -52.3333     81.00        89          40
# 7           Pouebo -20.4000  164.5667     84.63        60          23
# 8          Ashland  40.8167  -82.2665     55.40        67          40
# 9       Burns Lake  54.2331 -125.7533     41.00        56         100
#
#    Wind Speed Country Current Description
# 0       17.92      PF          light rain
# 1       11.50      BR           clear sky
# 2        6.29      CN       broken clouds
# 3        9.66      AU    scattered clouds
# 4        7.07      LR           clear sky
# 5       19.30      PF    scattered clouds
# 6        6.91      GF    scattered clouds
# 7        8.95      NC          few clouds
# 8        8.05      US    scattered clouds
# 9        6.91      CA     overcast clouds

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Rikitea      PF -23.1203 -134.9692     79.00        72
# 1    Arraial Do Cabo      BR -22.9661  -42.0278     78.80        83
# 2           Jinchang      CN  38.4953  102.1739     47.73        16
# 3       Port Lincoln      AU -34.7333  135.8667     65.08        59
# 4             Harper      LR   4.3750   -7.7169     78.30        90
# ..               ...     ...      ...       ...       ...       ...
# 658       Novoagansk      RU  61.9449   76.6625     31.68        97
# 659            Kieta      PG  -6.2167  155.6333     83.17        78
# 660         San Jose      US  37.3394 -121.8950     72.00        21
# 661           Miyako      JP  39.6367  141.9525     45.07        58
# 662       Baker City      US  44.7749 -117.8344     51.80        37
#
#      Cloudiness  Wind Speed Current Description
# 0             1       17.92          light rain
# 1             0       11.50           clear sky
# 2            82        6.29       broken clouds
# 3            33        9.66    scattered clouds
# 4             1        7.07           clear sky
# ..          ...         ...                 ...
# 658         100        9.04          light snow
# 659          99        7.36       moderate rain
# 660           1       11.50           clear sky
# 661          69        3.27       broken clouds
# 662          75       11.50       broken clouds
#
# [663 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# End of Deliverable One.
